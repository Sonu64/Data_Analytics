# %%
print("Jupyter successfuly working with Conda !")
# Out:
# Jupyter successfuly working with Conda !

# %%
print("Shortcut to Add Cell: Alt + Enter\nShortcut to Run Cell: Ctrl + Enter")
# Out:
# Shortcut to Add Cell: Alt + Enter
# Shortcut to Run Cell: Ctrl + Enter

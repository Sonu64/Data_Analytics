# %%
import numpy as np
np.__version__ # Special Dunder Attribute
# Out:
# '2.3.5'

# %%
array = np.array([10, 20, 30, 40])
print(type(array))
# Out:
# <class 'numpy.ndarray'>

# %%
doubledArr = array * 2
print(doubledArr)
# Out:
# [20 40 60 80]

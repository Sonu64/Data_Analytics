# %%
import pandas as pd
from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

df.info() # ----> Shows that 'job_posted_date' is a type of "OBJECT", but cleaning the data means that we have to convert this to appropiate type, i.e:- datetime
print("\n\n\n_______________________\n\n\n" + str(type(df['job_posted_date'])), end = "\n\n\n___________________\n\n\n") # ------> OBJECT, (pandas.core.series.Series)
# Converting the job_posted_date column to 'datetime64' object, and then reassigning to original df, as the method returns a new column with updated types
df['job_posted_date'] = pd.to_datetime(df.job_posted_date) # One uses subscript method, one uses Dot Operator, useful for these kind of updates
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

# Convert job_posted_date column to pandas datetime object
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# Once a Column is of type datetime(64), the .dt property can be accessed on the values to select specific parts of the date like month, year, day, etc....
print("DD: " + str(df['job_posted_date'].dt.day))
print("MM: " + str(df['job_posted_date'].dt.month))
print("YYYY: " + str(df['job_posted_date'].dt.year))


# Create a new Column in the Dataframe object with that new data received, Only Supports SUBSCRIPT notation !!!!!
df['job_posted_month'] = df['job_posted_date'].dt.month;

# Show updated Dataframe
df.info()
# Out:
# DD: 0         16
# 1         14
# 2         10
# 3          4
# 4          7
#           ..
# 785736    13
# 785737    12
# 785738    12
# 785739    12
# 785740    13
# Name: job_posted_date, Length: 785741, dtype: int32
# MM: 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32
# YYYY: 0         2023
# 1         2023
# 2         2023
# 3         2023
# 4         2023
#           ...
# 785736    2023
# 785737    2023
# 785738    2023
# 785739    2023
# 785740    2023
# Name: job_posted_date, Length: 785741, dtype: int32
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
# ...

# %%
"""SORTING ROWS BY THE VALUES OF A PARTICULAR COLUMN"""

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

# Convert job_posted_date column to pandas datetime object
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)


# Create a new Column in the Dataframe object with that new data received, Only Supports SUBSCRIPT notation !!!!!
df['job_posted_month'] = df['job_posted_date'].dt.month;
# df.sort_values(by = column_name, inplace = True or False based on wheather in-place sorting required or not)
# Not in-place ---> Reassigning to original df
# df = df.sort_values(by = "job_posted_month", inplace = False), below we are printing only the job_posted_month column of those Rows
df = df.sort_values(by = "job_posted_month", ascending=False, inplace = False)
print("Sort by job_posted_month and then Select only the job_posted_month column, Descending Order \n")
print(df['job_posted_month'], end = "\n\n\n")

# Create a new column called job_posted_year
df['job_posted_day'] = df['job_posted_date'].dt.day
# df.info()
# In-place Sort
df.sort_values(by = 'job_posted_day', inplace = True)
# Then select Last 30 Rows only the 'job_posted_day' column from those rows to check for Sort
print(df.job_posted_day.tail(100000))
# Out:
# Sort by job_posted_month and then Select only the job_posted_month column, Descending Order
#
# 719556    12
# 174416    12
# 676379    12
# 324564    12
# 723804    12
#           ..
# 693457     1
# 271747     1
# 271789     1
# 693447     1
# 303679     1
# Name: job_posted_month, Length: 785741, dtype: int32
#
#
# 394679    27
# 399442    27
# 176397    27
# 395055    27
# 90719     27
#           ..
# 523533    31
# 203212    31
# 203127    31
# 191036    31
# 167617    31
# Name: job_posted_day, Length: 100000, dtype: int32

# %%
"""REMOVING COLUMNS THAT ARE IRRELEVANT"""

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

# In-Place = False, has to reassign
# df.drop(labels = 'hourly_salary_avg', axis = 1) # Axis = 1 ----> Perform the operation of DROP along the Column axis, i.e -> Perform operation on Columns --> Drop that Column from a particular Row

df.drop(labels = 'salary_hour_avg', axis = 1, inplace = True)
df.info() # Now hourly_salary_avg Column is gone !!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
"""REMOVING THOSE ROWS WITH na VALUES IN A COLUMN"""
from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

# Reassigning, inplace = False
# df = df.dropna(axis = 0, subset = ['salary_year_avg'], inplace = True)

#inplace = True
df.dropna(axis = 0, subset = ['salary_year_avg'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  object
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
#.info() to get All important information about the Dataset

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
# Get all numerical information like max, min, count, etc. about the Numerical Columns of the Dataframe

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

print(df.describe())
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
# Get Unique Values from a particular column

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

print(df['job_title_short'].unique())
# Out:
# ['Senior Data Engineer' 'Data Analyst' 'Data Engineer' 'Business Analyst'
#  'Data Scientist' 'Machine Learning Engineer' 'Senior Data Analyst'
#  'Cloud Engineer' 'Senior Data Scientist' 'Software Engineer']

# %%
# Booolean condition of ROws to see a particular column condition is met or not

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

print(df['job_title_short'] == 'Business Analyst') # Prints a table of Boolean TRUE or FALSE values, TRUE if the row has job_title_short == 'Business Analyst', FALSE otherwise
# THESE CONDITIONS ARE USED BELOW TO CHECK FOR MULTIPLE CONDITIONS AND PRINT SPECIFIC ROWS
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738     True
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
# Getting Rows with One or multiple conditions for the column values

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME


# Select those rows only matching the column value conditions below
print(df[ (df.job_title_short == 'Business Analyst') | (df.job_title_short == 'Data Analyst') ], end = "\n\n\n---------------------------------------\n\n\n")

# Select those rows only matching the column value conditions below, then select the subscripted columns from those rows.
print(df[(df['job_title_short'] == 'Software Engineer') & (df['salary_year_avg']>100000) & (df['job_location'] == 'San Jose, CA')][['job_title_short', 'salary_year_avg', 'job_location', 'salary_hour_avg']], end = "\n\n\n---------------------------------------\n\n\n")

# For single column selection, List of column names is optional, only df['column_name'] also works fine.
print(df[['job_title_short']]) # ------> A Dataframe returned, BuT df['column_name'] returns a Series
# Out:
#          job_title_short                                    job_title  \
# 1           Data Analyst                                 Data Analyst
# 8       Business Analyst     Technology & Operations Business Analyst
# 12          Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18          Data Analyst                                 Data Analyst
# 31          Data Analyst                     Stage - Data Analyst F/H
# ...                  ...                                          ...
# 785721  Business Analyst                     IT Business Analyst Data
# 785722  Business Analyst   Business Analytics Training and Internship
# 785734  Business Analyst                            PreSales Engineer
# 785737      Data Analyst                             CRM Data Analyst
# 785738  Business Analyst               Commercial Analyst - Start Now
#
#                         job_location                    job_via  \
# ...

# %%
# df.notna() - displays if the values are not NA (missing values).
# It returns a Boolean same-sized object indicating if the values are not NA.
# Non-missing values are True
# Missing values are False

from datasets import load_dataset
ds = load_dataset("lukebarousse/data_jobs") # Type is DatasetDict
training_data = ds['train'] # Get the training data from the dataset
df = training_data.to_pandas() # CONVERT TO A PANDAS DATAFRAME

print(df['salary_year_avg'].notna(), end = "\n\n\n") # Boolean Table
# Combine conditions
# Print only those rows where either of Yearly Salary Avg and Hourly Salary Avg are not NA.
print(df[ df['salary_year_avg'].notna() | df['salary_hour_avg'].notna() ], end = "\n\n\n")

# apply this to the entire DataFrame to get a boolean DataFrame indicating where values aren't missing.
print(df.notna())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool
#
#
#              job_title_short  \
# 28            Data Scientist
# 43      Senior Data Engineer
# 51      Senior Data Engineer
# 77             Data Engineer
# 92             Data Engineer
# ...                      ...
# 785624         Data Engineer
# 785641         Data Engineer
# 785648        Data Scientist
# 785682        Data Scientist
# 785692        Data Scientist
#
#                                                 job_title  \
# 28                                    CRM Data Specialist
# 43      Sr SQL Database Engineer with Data Warehouse /...
# 51                                   Senior Data Engineer
# 77                                          Data Engineer
# 92                Remote - Data Engineer - Permanent - W2
# ...

# %%
# Import Entire Module
import sample_functions
print(sample_functions.favSkill("Java"))
# Out:
# My favourite skill is Java !

# %%
print(sample_functions.finalPrice(10000, 50))
# Out:
# 5000.0

# %%
# Import a Specific function from Module
from sample_functions import greet
greet("Sourakanti")
# Out:
# 'Welcome to Data Analysis, Sourakanti !'

# %%
# Import all functions/variables from a module using wildcard * operator
from sample_functions import *
print(sample_functions.finalPrice(10, 10))
# Out:
# 9.0

# %%
# Adding DOCStrings to Python functions in module to show a detailed help(function_name)
help(sample_functions.finalPrice)
# Out:
# Help on function finalPrice in module sample_functions:
#
# finalPrice(amount, discountPercentage)
#     Calculates final Price after applying discount of <discountPercentage> on it.
#
#     Args:
#     amount(int): Original Price
#     discountPercentage(int): Percentage Discount
#
#     Returns:
#     finalAmount(float): Price after applying Discount

# %%
# Pythons built-in Modules -> Using statistics here
from statistics import mean, median, mode
nums = [10, 20, 30, 40, 50];
print(mean(nums))
print(median(nums))
print(mode(nums))
# Out:
# 30
# 30
# 10

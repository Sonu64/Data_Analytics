# %%
import pandas as pd

dataframe = pd.read_csv('sample_data.csv')

print(dataframe)
print(dataframe['ID'].sum())
print(dataframe['Age'].sum())
# Out:
#        ID      Name  Age    Country                  Email
# 0     1.0    Name_1   62  Country_1    email_1@example.com
# 1     2.0    Name_2   48  Country_2    email_2@example.com
# 2     3.0    Name_3   61  Country_3    email_3@example.com
# 3     4.0    Name_4   32  Country_4    email_4@example.com
# 4     5.0    Name_5   69  Country_5    email_5@example.com
# ..    ...       ...  ...        ...                    ...
# 95   96.0   Name_96   60  Country_6   email_96@example.com
# 96   97.0   Name_97   26  Country_7   email_97@example.com
# 97   98.0   Name_98   52  Country_8   email_98@example.com
# 98   99.0   Name_99   24  Country_9   email_99@example.com
# 99  100.0  Name_100   55  Country_0  email_100@example.com
#
# [100 rows x 5 columns]
# 4974.0
# 4453
